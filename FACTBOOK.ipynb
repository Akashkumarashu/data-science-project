# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashkumarashu/data-science-project/blob/main/FACTBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3 as sql
con=sql.connect("factbook.db")

# %%
import pandas as pd

# %%
fact_df=pd.read_sql_query("select * from facts where id>3",con)

# %%
fact_df
# Out:
#       id code                 name       area  area_land  area_water  \
# 0      4   an              Andorra      468.0      468.0         0.0
# 1      5   ao               Angola  1246700.0  1246700.0         0.0
# 2      6   ac  Antigua and Barbuda      442.0      442.0         0.0
# 3      7   ar            Argentina  2780400.0  2736690.0     43710.0
# 4      8   am              Armenia    29743.0    28203.0      1540.0
# ..   ...  ...                  ...        ...        ...         ...
# 253  257   zh       Atlantic Ocean        NaN        NaN         NaN
# 254  258   xo         Indian Ocean        NaN        NaN         NaN
# 255  259   zn        Pacific Ocean        NaN        NaN         NaN
# 256  260   oo       Southern Ocean        NaN        NaN         NaN
# 257  261   xx                World        NaN        NaN         NaN
#
#        population  population_growth  birth_rate  death_rate  migration_rate  \
# ...

# %%
# merged=pd.merge(cities_df,facts_df,how='left',on='facts_id')
d={"City":["Delhi","Mumbai","Pune","Banglore","Chennai","Kolkata"],"Temperature":[45.8,35.4,37.8,25.6,47,35]}
df=pd.DataFrame(d)

# %%
df
# Out:
#        City  Temperature
# 0     Delhi         45.8
# 1    Mumbai         35.4
# 2      Pune         37.8
# 3  Banglore         25.6
# 4   Chennai         47.0
# 5   Kolkata         35.0

# %%
d2={"City":["Delhi","Mumbai","Pune","Banglore","Chennai","Kolkata"],"Humidity":[50,98,78,87,99,25]}

# %%
df2=pd.DataFrame(d2)

# %%
df2
# Out:
#        City  Humidity
# 0     Delhi        50
# 1    Mumbai        98
# 2      Pune        78
# 3  Banglore        87
# 4   Chennai        99
# 5   Kolkata        25

# %%
merged=pd.merge(df,df2, on="City")

# %%
merged
# Out:
#        City  Temperature  Humidity
# 0     Delhi         45.8        50
# 1    Mumbai         35.4        98
# 2      Pune         37.8        78
# 3  Banglore         25.6        87
# 4   Chennai         47.0        99
# 5   Kolkata         35.0        25

# %%
d3={"City":["Delhi","Mumbai","Pune","Chennai","Kolkata"],"Population in Crore":[1.5,1,0.5,0.8,1.1]}

# %%
df3=pd.DataFrame(d3)
merged2=pd.merge(merged,df3,on="City",how="left")

# %%
merged2
# Out:
#        City  Temperature  Humidity  Population in Crore
# 0     Delhi         45.8        50                  1.5
# 1    Mumbai         35.4        98                  1.0
# 2      Pune         37.8        78                  0.5
# 3  Banglore         25.6        87                  NaN
# 4   Chennai         47.0        99                  0.8
# 5   Kolkata         35.0        25                  1.1
